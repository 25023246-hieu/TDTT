# %%
print("hello word")
# Out:
# hello word

# %%
a = list ( map (int ,input().split()))
a. sort(reverse=True)
print (a)
# Out:
# [33, 2, 2, 1, 1]

# %%
s = input()
for i in s :
    if i =="{":
        if i+1 =="}" :

# %%
print('*'* 2)
# Out:
# **

# %%
a=4
b=5
print(a+b)
# Out:
# 9
