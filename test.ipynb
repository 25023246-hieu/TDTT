# %%
print("hello word")
# Out:
# hello word

# %%
a = list ( map (int ,input().split()))
a. sort(reverse=True)
print (a)
# Out:
# [3, 2, 2]

# %%
a = [ 1 ,3 ,2]
a.reverse()
print(a)
# Out:
# [2, 3, 1]

# %%
n = list(map (int , input().split()))
k =int (input())
for i in range (len(n)) :
        if n[i] == k :
            print (i,end=' ')
# Out:
# 2 5
